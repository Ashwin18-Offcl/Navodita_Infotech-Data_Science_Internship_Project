# %% [markdown]
# # Smart Product Recommendation System
# Collaborative Filtering using Surprise Library

# %%
# !pip install scikit-surprise

import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting joblib>=1.2.0 (from scikit-surprise)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ashwin\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from scikit-surprise) (2.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ashwin\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from scikit-surprise) (1.14.1)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml): started
#   Building wheel for scikit-surprise (pyproject.toml): finished with status 'done'
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp312-cp312-win_amd64.whl size=1319712 sha256=ae8e0a404345d9489704323a6c8a51b8df9dfbe0dc5e16d0829140eff86e167d
#   Stored in directory: c:\users\ashwin\appdata\local\pip\cache\wheels\75\fa\bc\739bc2cb1fbaab6061854e6cfbb81a0ae52c92a502a7fa454b
# Successfully built scikit-surprise
# Installing collected packages: joblib, scikit-surprise
# Successfully installed joblib-1.5.3 scikit-surprise-1.1.4
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ASHWIN\AppData\Local\Temp\ipykernel_32668\2919562120.py", line 4, in <module>
#     from surprise import Dataset, Reader, SVD
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\surprise\__init__.py", line 6, in <module>
#     from .prediction_algorithms import (
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\surprise\prediction_algorithms\__init__.py", line 23, in <module>
#     from .algo_base import AlgoBase
#   File "\\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\surprise\prediction_algorithms\algo_base.py", line 8, in <module>
#     from .. import similarities as sims
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 4
#       1 get_ipython().system('pip install scikit-surprise')
#       3 import pandas as pd
# ----> 4 from surprise import Dataset, Reader, SVD
#       5 from surprise.model_selection import train_test_split
#
# File \\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\surprise\__init__.py:6
#       2 from .builtin_datasets import get_dataset_dir
#       4 from .dataset import Dataset
# ----> 6 from .prediction_algorithms import (
#       7     AlgoBase,
#       8     BaselineOnly,
#       9     CoClustering,
#      10     KNNBaseline,
#      11     KNNBasic,
#      12     KNNWithMeans,
#      13     KNNWithZScore,
#      14     NMF,
#      15     NormalPredictor,
#      16     Prediction,
#      17     PredictionImpossible,
#      18     SlopeOne,
#      19     SVD,
#      20     SVDpp,
#      21 )
#      22 from .reader import Reader
#      23 from .trainset import Trainset
#
# File \\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\surprise\prediction_algorithms\__init__.py:23
#       1 """
#       2 The :mod:`prediction_algorithms` package includes the prediction algorithms
#       3 available for recommendation.
#    (...)
#      20     co_clustering.CoClustering
#      21 """
# ---> 23 from .algo_base import AlgoBase
#      24 from .baseline_only import BaselineOnly
#      25 from .co_clustering import CoClustering
#
# File \\?\C:\Users\ASHWIN\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\surprise\prediction_algorithms\algo_base.py:8
#       1 """
#       2 The :mod:`surprise.prediction_algorithms.algo_base` module defines the base
#       3 class :class:`AlgoBase` from which every single prediction algorithm has to
#       4 inherit.
#       5 """
#       6 import heapq
# ----> 8 from .. import similarities as sims
#       9 from .optimize_baselines import baseline_als, baseline_sgd
#      10 from .predictions import Prediction, PredictionImpossible
#
# File surprise/similarities.pyx:1, in init surprise.similarities()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).

# %%
# Load dataset
df = pd.read_csv('ratings.csv')
df.head()

# %%
# Prepare data for Surprise
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['userId', 'itemId', 'rating']], reader)

# %%
# Train-test split
trainset, testset = train_test_split(data, test_size=0.2)

# %%
# Train model
model = SVD()
model.fit(trainset)

# %%
# Make prediction
pred = model.predict(1, 101)
print(pred)
